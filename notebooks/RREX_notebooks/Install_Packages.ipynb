# %%
# Run this in a Jupyter notebook cell
import sys
# !{sys.executable} -m pip install seawater
# !{sys.executable} -m pip install xarray
# !{sys.executable} -m pip install scipy
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install cmocean
# !{sys.executable} -m pip install gsw
# !{sys.executable} -m pip install cartopy

# Or if that doesn't work:
#!pip install seawater
# Out:
# ...
#   Using cached seawater-3.3.5-py3-none-any.whl.metadata (3.7 kB)
# ...
# Using cached seawater-3.3.5-py3-none-any.whl (25 kB)
# ...

# %%
from ocean_functions import interpolate_to
